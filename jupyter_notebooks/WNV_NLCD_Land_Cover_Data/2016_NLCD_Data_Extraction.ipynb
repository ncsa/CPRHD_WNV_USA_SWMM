# %% [markdown]
# ## Purpose:
#
# To get 2016 NLCD Land Cover data for the urban counties
#
# #### Import

# %%
import rasterstats as rs
import geopandas as gpd
import rasterio as rio

import pandas as pd

import glob
import os

# %% [markdown]
# #### Load Urban County Shapefile, NLCD Land Cover GeoTIFF
#
# <img src="https://i.imgur.com/sN5uH08.png">

# %%
path_to_urban_counties = '../shapefile/urban_counties_wnv_4326.gpkg'
path_to_nlcd_land_cover = './NLCD.geotiff'

assert os.path.exists(path_to_urban_counties), 'Failed to find urban county shapefile'
assert os.path.exists(path_to_nlcd_land_cover), 'Failed to find land cover image'

# %% [markdown]
# #### Zonal Stats: all_touched=True

# %%
stats = rs.zonal_stats(path_to_urban_counties, path_to_nlcd_land_cover, categorical=True, all_touched=True)

# %%
frame = pd.DataFrame.from_dict(stats)

# %%
urban_counties = gpd.read_file(path_to_urban_counties)
frame = frame.join([urban_counties['GEOID'], urban_counties['NAME']])
frame = frame.set_index('GEOID', drop=True)

# %%
frame
# Out:
#              11      21      22     23     24    31         41        42  \
# GEOID
# 31109   30742.0   93549  117726  61618  27818   906   104044.0     294.0
# 46099   31110.0  127943   57238  41687  18492  4529    28025.0      13.0
# 39003   10949.0   91319   61203  20170  12316   508    84701.0     671.0
# 42007   22639.0  124920   69074  33639  18794  2561   601300.0    2387.0
# 37037   71936.0   98476   20782   6929   2125  2108   459118.0  328956.0
# ...         ...     ...     ...    ...    ...   ...        ...       ...
# 42129   27066.0  202212  166130  77265  22318  8819  1186749.0    5645.0
# 12015  358979.0  176011  109534  36098   7742  3331     4141.0   36196.0
# 44003   48082.0   36260   43297  56206  17368  3657   104502.0   37624.0
# 28089   64148.0   92764   49725  25501   6002   607   121627.0  264340.0
# 54099   16912.0   46564   28053  10986   2174  2883  1059000.0    3553.0
#
#              43       52      71        81         82        90        95  \
# GEOID
# 31109    2651.0    876.0  485357   43609.0  1219635.0    6684.0    9730.0
# 46099    1438.0     57.0   63475  257074.0  1544300.0    1187.0   41440.0
# 39003     774.0    104.0    7452   33051.0   731914.0    3062.0    2628.0
# 42007   80424.0   3711.0    8500  151124.0    31616.0    4025.0    1191.0
# 37037  310211.0  43254.0   69626  266940.0    21959.0   22121.0    1562.0
# ...         ...      ...     ...       ...        ...       ...       ...
# 42129  431155.0   7391.0   20274  303965.0   219900.0    3985.0    1113.0
# 12015   17142.0  73797.0   10036  278643.0    61691.0  523675.0  207939.0
# 44003   90957.0   1891.0    4889    5641.0      622.0   45132.0    2075.0
# 28089  257355.0  33615.0   39291  419411.0   116880.0  233006.0   19787.0
# 54099   57990.0   8724.0   10171   40624.0      232.0     251.0       5.0
#
#            0  12          NAME
# GEOID
# 31109    NaN NaN     Lancaster
# 46099    NaN NaN     Minnehaha
# 39003    NaN NaN         Allen
# 42007    NaN NaN        Beaver
# 37037    NaN NaN       Chatham
# ...      ...  ..           ...
# 42129    NaN NaN  Westmoreland
# 12015  304.0 NaN     Charlotte
# 44003    NaN NaN          Kent
# 28089    NaN NaN       Madison
# 54099    NaN NaN         Wayne
#
# [852 rows x 18 columns]

# %%
frame.to_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched.pkl')

# %% [markdown]
# #### Zonal Stats: all_touched = False

# %%
new_stats = rs.zonal_stats(path_to_urban_counties, path_to_nlcd_land_cover, categorical=True)
# Out:
# /home/matas/anaconda3/envs/swmm/lib/python3.7/site-packages/rasterstats/io.py:301: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
new_frame = pd.DataFrame.from_dict(new_stats)

# %%
urban_counties = gpd.read_file(path_to_urban_counties)
new_frame = new_frame.join([urban_counties['GEOID'], urban_counties['NAME']])
new_frame = new_frame.set_index('GEOID', drop=True)

# %%
new_frame
# Out:
#              11      21      22     23     24    31         41        42  \
# GEOID
# 31109   30741.0   91755  117482  61610  27818   906   104008.0     294.0
# 46099   31020.0  126950   57173  41663  18488  4529    28013.0      13.0
# 39003   10949.0   90418   61040  20142  12303   508    84500.0     671.0
# 42007   22610.0  124676   68937  33577  18787  2561   600264.0    2386.0
# 37037   70783.0   98291   20740   6897   2122  2108   458254.0  328402.0
# ...         ...     ...     ...    ...    ...   ...        ...       ...
# 42129   24008.0  201693  165791  77109  22291  8791  1184674.0    5605.0
# 12015  358244.0  175636  109321  36054   7739  3318     4135.0   36083.0
# 44003   47566.0   36110   43185  56136  17346  3656   104023.0   37528.0
# 28089   62482.0   92559   49657  25486   5998   571   121387.0  264103.0
# 54099   16177.0   46282   27842  10919   2164  2860  1056304.0    3546.0
#
#              43       52      71        81         82        90        95  \
# GEOID
# 31109    2651.0    876.0  485017   43572.0  1219200.0    6684.0    9730.0
# 46099    1438.0     57.0   63431  256971.0  1543701.0    1187.0   41419.0
# 39003     771.0    104.0    7446   33025.0   730799.0    3061.0    2628.0
# 42007   80197.0   3706.0    8497  150870.0    31527.0    4006.0    1184.0
# 37037  309711.0  43196.0   69511  266550.0    21929.0   21995.0    1549.0
# ...         ...      ...     ...       ...        ...       ...       ...
# 42129  430823.0   7391.0   20227  303776.0   219859.0    3904.0    1101.0
# 12015   17112.0  73604.0    9993  277908.0    61573.0  522958.0  207821.0
# 44003   90604.0   1871.0    4884    5628.0      621.0   44838.0    2060.0
# 28089  256998.0  33571.0   39209  419154.0   116859.0  231656.0   19283.0
# 54099   57872.0   8695.0   10005   40526.0      231.0     240.0       5.0
#
#           0  12          NAME
# GEOID
# 31109   NaN NaN     Lancaster
# 46099   NaN NaN     Minnehaha
# 39003   NaN NaN         Allen
# 42007   NaN NaN        Beaver
# 37037   NaN NaN       Chatham
# ...     ...  ..           ...
# 42129   NaN NaN  Westmoreland
# 12015  44.0 NaN     Charlotte
# 44003   NaN NaN          Kent
# 28089   NaN NaN       Madison
# 54099   NaN NaN         Wayne
#
# [852 rows x 18 columns]

# %%
new_frame.to_pickle('./urban_county_data/NLCD_Urban_Counties.pkl')

# %% [markdown]
# ### Convert Pixel Values to Land Cover Categories (ex. 11 --> Open Water)

# %%
key = {11: 'open_water',
       12: 'perennial_ice',
       
       21: 'developed_open',
       22: 'developed_low',
       23: 'developed_medium',
       24: 'developed_high',
       
       31: 'barren_land',
       41: 'deciduous_forest',
       42: 'evergreen_forest',
       43: 'mixed_forest',
       
       51: 'dwarf_scrub',  # alaska only
       52: 'shrub',
       71: 'grassland',
       
       72: 'sedge',  # alaska only
       73: 'lichens',  # alaska only
       74: 'moss',  # alaska only
       
       81: 'pasture_hay',
       82: 'cultivated_crops',
       90: 'woody_wetlands',
       95: 'emergent_herbaceous_wetlands'
      }

# %%
all_touched = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched.pkl')
all_touched = all_touched.rename(columns=key)
all_touched.to_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched_keyed.pkl')
all_touched
# Out:
#        open_water  developed_open  developed_low  developed_medium  \
# GEOID
# 31109     30742.0           93549         117726             61618
# 46099     31110.0          127943          57238             41687
# 39003     10949.0           91319          61203             20170
# 42007     22639.0          124920          69074             33639
# 37037     71936.0           98476          20782              6929
# ...           ...             ...            ...               ...
# 42129     27066.0          202212         166130             77265
# 12015    358979.0          176011         109534             36098
# 44003     48082.0           36260          43297             56206
# 28089     64148.0           92764          49725             25501
# 54099     16912.0           46564          28053             10986
#
#        developed_high  barren_land  deciduous_forest  evergreen_forest  \
# GEOID
# 31109           27818          906          104044.0             294.0
# 46099           18492         4529           28025.0              13.0
# 39003           12316          508           84701.0             671.0
# 42007           18794         2561          601300.0            2387.0
# 37037            2125         2108          459118.0          328956.0
# ...               ...          ...               ...               ...
# 42129           22318         8819         1186749.0            5645.0
# 12015            7742         3331            4141.0           36196.0
# 44003           17368         3657          104502.0           37624.0
# 28089            6002          607          121627.0          264340.0
# 54099            2174         2883         1059000.0            3553.0
#
#        mixed_forest    shrub  grassland  pasture_hay  cultivated_crops  \
# GEOID
# 31109        2651.0    876.0     485357      43609.0         1219635.0
# 46099        1438.0     57.0      63475     257074.0         1544300.0
# 39003         774.0    104.0       7452      33051.0          731914.0
# 42007       80424.0   3711.0       8500     151124.0           31616.0
# 37037      310211.0  43254.0      69626     266940.0           21959.0
# ...             ...      ...        ...          ...               ...
# 42129      431155.0   7391.0      20274     303965.0          219900.0
# 12015       17142.0  73797.0      10036     278643.0           61691.0
# 44003       90957.0   1891.0       4889       5641.0             622.0
# 28089      257355.0  33615.0      39291     419411.0          116880.0
# 54099       57990.0   8724.0      10171      40624.0             232.0
#
#        woody_wetlands  emergent_herbaceous_wetlands      0  perennial_ice  \
# GEOID
# 31109          6684.0                        9730.0    NaN            NaN
# 46099          1187.0                       41440.0    NaN            NaN
# 39003          3062.0                        2628.0    NaN            NaN
# 42007          4025.0                        1191.0    NaN            NaN
# 37037         22121.0                        1562.0    NaN            NaN
# ...               ...                           ...    ...            ...
# 42129          3985.0                        1113.0    NaN            NaN
# 12015        523675.0                      207939.0  304.0            NaN
# 44003         45132.0                        2075.0    NaN            NaN
# 28089        233006.0                       19787.0    NaN            NaN
# 54099           251.0                           5.0    NaN            NaN
#
#                NAME
# GEOID
# 31109     Lancaster
# 46099     Minnehaha
# 39003         Allen
# 42007        Beaver
# 37037       Chatham
# ...             ...
# 42129  Westmoreland
# 12015     Charlotte
# 44003          Kent
# 28089       Madison
# 54099         Wayne
#
# [852 rows x 18 columns]

# %%
frame = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties.pkl')
frame = frame.rename(columns=key)
frame.to_pickle('./urban_county_data/NLCD_Urban_Counties_keyed.pkl')
frame
# Out:
#        open_water  developed_open  developed_low  developed_medium  \
# GEOID
# 31109     30741.0           91755         117482             61610
# 46099     31020.0          126950          57173             41663
# 39003     10949.0           90418          61040             20142
# 42007     22610.0          124676          68937             33577
# 37037     70783.0           98291          20740              6897
# ...           ...             ...            ...               ...
# 42129     24008.0          201693         165791             77109
# 12015    358244.0          175636         109321             36054
# 44003     47566.0           36110          43185             56136
# 28089     62482.0           92559          49657             25486
# 54099     16177.0           46282          27842             10919
#
#        developed_high  barren_land  deciduous_forest  evergreen_forest  \
# GEOID
# 31109           27818          906          104008.0             294.0
# 46099           18488         4529           28013.0              13.0
# 39003           12303          508           84500.0             671.0
# 42007           18787         2561          600264.0            2386.0
# 37037            2122         2108          458254.0          328402.0
# ...               ...          ...               ...               ...
# 42129           22291         8791         1184674.0            5605.0
# 12015            7739         3318            4135.0           36083.0
# 44003           17346         3656          104023.0           37528.0
# 28089            5998          571          121387.0          264103.0
# 54099            2164         2860         1056304.0            3546.0
#
#        mixed_forest    shrub  grassland  pasture_hay  cultivated_crops  \
# GEOID
# 31109        2651.0    876.0     485017      43572.0         1219200.0
# 46099        1438.0     57.0      63431     256971.0         1543701.0
# 39003         771.0    104.0       7446      33025.0          730799.0
# 42007       80197.0   3706.0       8497     150870.0           31527.0
# 37037      309711.0  43196.0      69511     266550.0           21929.0
# ...             ...      ...        ...          ...               ...
# 42129      430823.0   7391.0      20227     303776.0          219859.0
# 12015       17112.0  73604.0       9993     277908.0           61573.0
# 44003       90604.0   1871.0       4884       5628.0             621.0
# 28089      256998.0  33571.0      39209     419154.0          116859.0
# 54099       57872.0   8695.0      10005      40526.0             231.0
#
#        woody_wetlands  emergent_herbaceous_wetlands     0  perennial_ice  \
# GEOID
# 31109          6684.0                        9730.0   NaN            NaN
# 46099          1187.0                       41419.0   NaN            NaN
# 39003          3061.0                        2628.0   NaN            NaN
# 42007          4006.0                        1184.0   NaN            NaN
# 37037         21995.0                        1549.0   NaN            NaN
# ...               ...                           ...   ...            ...
# 42129          3904.0                        1101.0   NaN            NaN
# 12015        522958.0                      207821.0  44.0            NaN
# 44003         44838.0                        2060.0   NaN            NaN
# 28089        231656.0                       19283.0   NaN            NaN
# 54099           240.0                           5.0   NaN            NaN
#
#                NAME
# GEOID
# 31109     Lancaster
# 46099     Minnehaha
# 39003         Allen
# 42007        Beaver
# 37037       Chatham
# ...             ...
# 42129  Westmoreland
# 12015     Charlotte
# 44003          Kent
# 28089       Madison
# 54099         Wayne
#
# [852 rows x 18 columns]

# %% [markdown]
# ### Convert Pixel Counts to Percentages
#
# The following function will take a row of the dataframe (a GEOID) and convert its values to percentages.

# %%
def convert_to_percent(row):
    total = row.sum()
    for land_type in row.index:
        row[land_type] = row[land_type] / total * 100
    return row

# %%
all_touched = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched_keyed.pkl')
data = all_touched.iloc[:,:-1]  # ignore the NAME column
data = data.apply(convert_to_percent, axis='columns')
data = data.join(all_touched['NAME'])

data.to_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched_keyed_percentage.pkl')
data
# Out:
#        open_water  developed_open  developed_low  developed_medium  \
# GEOID
# 31109    1.394044        4.242125       5.338469          2.794164
# 46099    1.402610        5.768374       2.580604          1.879479
# 39003    1.032124        8.608324       5.769394          1.901356
# 42007    1.958552       10.807117       5.975751          2.910187
# 37037    4.167538        5.705106       1.203984          0.401424
# ...           ...             ...            ...               ...
# 42129    1.008425        7.534016       6.189672          2.878740
# 12015   18.841480        9.238167       5.749035          1.894651
# 44003    9.651086        7.278158       8.690634         11.281747
# 28089    3.678087        5.318857       2.851108          1.462164
# 54099    1.312919        3.614875       2.177822          0.852870
#
#        developed_high  barren_land  deciduous_forest  evergreen_forest  \
# GEOID
# 31109        1.261451     0.041084          4.718037          0.013332
# 46099        0.833721     0.204192          1.263521          0.000586
# 39003        1.160986     0.047887          7.984469          0.063253
# 42007        1.625912     0.221558         52.019846          0.206505
# 37037        0.123110     0.122125         26.598529         19.057727
# ...               ...          ...               ...               ...
# 42129        0.831524     0.328578         44.215900          0.210321
# 12015        0.406349     0.174832          0.217346          1.899794
# 44003        3.486129     0.734038         20.975787          7.551942
# 28089        0.344140     0.034804          6.973789         15.156597
# 54099        0.168773     0.223814         82.212710          0.275828
#
#        mixed_forest     shrub  grassland  pasture_hay  cultivated_crops  \
# GEOID
# 31109      0.120214  0.039724  22.009270     1.977518         55.306250
# 46099      0.064833  0.002570   2.861802    11.590310         69.625538
# 39003      0.072962  0.009804   0.702474     3.115603         68.994987
# 42007      6.957665  0.321047   0.735355    13.074085          2.735173
# 37037     17.971755  2.505876   4.033711    15.464894          1.272172
# ...             ...       ...        ...          ...               ...
# 42129     16.063975  0.275374   0.755369    11.325129          8.193035
# 12015      0.899720  3.873332   0.526753    14.624941          3.237932
# 44003     18.257016  0.379564   0.981327     1.132269          0.124849
# 28089     14.756095  1.927400   2.252848    24.047982          6.701608
# 54099      4.501903  0.677265   0.789599     3.153739          0.018011
#
#        woody_wetlands  emergent_herbaceous_wetlands         0  perennial_ice  \
# GEOID
# 31109        0.303096                      0.441222       NaN            NaN
# 46099        0.053516                      1.868343       NaN            NaN
# 39003        0.288644                      0.247732       NaN            NaN
# 42007        0.348212                      0.103036       NaN            NaN
# 37037        1.281557                      0.090493       NaN            NaN
# ...               ...                           ...       ...            ...
# 42129        0.148473                      0.041468       NaN            NaN
# 12015       27.485764                     10.913949  0.015956            NaN
# 44003        9.058958                      0.416497       NaN            NaN
# 28089       13.359984                      1.134537       NaN            NaN
# 54099        0.019486                      0.000388       NaN            NaN
#
#                NAME
# GEOID
# 31109     Lancaster
# 46099     Minnehaha
# 39003         Allen
# 42007        Beaver
# 37037       Chatham
# ...             ...
# 42129  Westmoreland
# 12015     Charlotte
# 44003          Kent
# 28089       Madison
# 54099         Wayne
#
# [852 rows x 18 columns]

# %%
frame = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_keyed.pkl')
data = frame.iloc[:,:-1]  # ignore the NAME column
data = data.apply(convert_to_percent, axis='columns')
data = data.join(frame['NAME'])

data.to_pickle('./urban_county_data/NLCD_Urban_Counties_keyed_percentage.pkl')
data
# Out:
#        open_water  developed_open  developed_low  developed_medium  \
# GEOID
# 31109    1.395831        4.166243       5.334407          2.797474
# 46099    1.399786        5.728654       2.579947          1.880054
# 39003    1.034520        8.543177       5.767386          1.903124
# 42007    1.959637       10.805826       5.974857          2.910161
# 37037    4.110420        5.707830       1.204387          0.400514
# ...           ...             ...            ...               ...
# 42129    0.896810        7.534171       6.193065          2.880380
# 12015   18.839648        9.236499       5.749068          1.896039
# 44003    9.588837        7.279420       8.705670         11.316464
# 28089    3.593040        5.322624       2.855536          1.465578
# 54099    1.260217        3.605449       2.168941          0.850609
#
#        developed_high  barren_land  deciduous_forest  evergreen_forest  \
# GEOID
# 31109        1.263109     0.041138          4.722605          0.013349
# 46099        0.834276     0.204372          1.264094          0.000587
# 39003        1.162453     0.047999          7.984013          0.063400
# 42007        1.628293     0.221965         52.025637          0.206798
# 37037        0.123226     0.122413         26.611143         19.070543
# ...               ...          ...               ...               ...
# 42129        0.832672     0.328385         44.253081          0.209373
# 12015        0.406985     0.174490          0.217455          1.897564
# 44003        3.496783     0.737014         20.970011          7.565275
# 28089        0.344916     0.032835          6.980384         15.187297
# 54099        0.168579     0.222799         82.287944          0.276240
#
#        mixed_forest     shrub  grassland  pasture_hay  cultivated_crops  \
# GEOID
# 31109      0.120372  0.039776  22.022763     1.978438         55.359199
# 46099      0.064890  0.002572   2.862341    11.595887         69.659931
# 39003      0.072848  0.009826   0.703538     3.120379         69.049808
# 42007      6.950775  0.321204   0.736446    13.076093          2.732485
# 37037     17.985143  2.508423   4.036554    15.478753          1.273433
# ...             ...       ...        ...          ...               ...
# 42129     16.093242  0.276088   0.755572    11.347446          8.212756
# 12015      0.899901  3.870751   0.525521    14.614868          3.238055
# 44003     18.264873  0.377175   0.984566     1.134549          0.125187
# 28089     14.778723  1.930507   2.254722    24.103537          6.720001
# 54099      4.508331  0.677356   0.779407     3.157047          0.017995
#
#        woody_wetlands  emergent_herbaceous_wetlands         0  perennial_ice  \
# GEOID
# 31109        0.303495                      0.441802       NaN            NaN
# 46099        0.053564                      1.869044       NaN            NaN
# 39003        0.289220                      0.248308       NaN            NaN
# 42007        0.347205                      0.102619       NaN            NaN
# 37037        1.277266                      0.089952       NaN            NaN
# ...               ...                           ...       ...            ...
# 42129        0.145833                      0.041127       NaN            NaN
# 12015       27.501771                     10.929072  0.002314            NaN
# 44003        9.038899                      0.415276       NaN            NaN
# 28089       13.321426                      1.108873       NaN            NaN
# 54099        0.018696                      0.000390       NaN            NaN
#
#                NAME
# GEOID
# 31109     Lancaster
# 46099     Minnehaha
# 39003         Allen
# 42007        Beaver
# 37037       Chatham
# ...             ...
# 42129  Westmoreland
# 12015     Charlotte
# 44003          Kent
# 28089       Madison
# 54099         Wayne
#
# [852 rows x 18 columns]

# %% [markdown]
# ## Data Validation

# %% [markdown]
# ### Compare all_touched=True to all_touched=False
#
# We need to compare the rasterization methods to see if it is worth keeping both data-sets, or just drop one of them

# %% [markdown]
# #### Mean Difference

# %%
all_touched = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched_keyed_percentage.pkl').iloc[:,:-1]
frame = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_keyed_percentage.pkl').iloc[:,:-1]
name = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_keyed_percentage.pkl').iloc[:,-1]

diff = frame - all_touched
diff.mean()
# Out:
# open_water                     -0.049410
# developed_open                 -0.001718
# developed_low                   0.006314
# developed_medium                0.007438
# developed_high                  0.005430
# barren_land                    -0.000169
# deciduous_forest                0.003555
# evergreen_forest                0.006178
# mixed_forest                    0.003779
# shrub                           0.001569
# grassland                       0.002272
# pasture_hay                     0.011245
# cultivated_crops                0.018905
# woody_wetlands                 -0.010483
# emergent_herbaceous_wetlands    0.000013
# 0                              -0.036400
# perennial_ice                  -0.000423
# dtype: float64

# %% [markdown]
# #### Max Difference

# %%
diff.max()
# Out:
# open_water                      0.161638
# developed_open                  0.514656
# developed_low                   0.663477
# developed_medium                0.680536
# developed_high                  0.291033
# barren_land                     0.044649
# deciduous_forest                0.258764
# evergreen_forest                0.144565
# mixed_forest                    0.224322
# shrub                           0.047364
# grassland                       0.100768
# pasture_hay                     0.223514
# cultivated_crops                0.270083
# woody_wetlands                  0.087645
# emergent_herbaceous_wetlands    0.073431
# 0                              -0.001578
# perennial_ice                   0.001849
# dtype: float64

# %% [markdown]
# #### Min Difference

# %%
diff.min()
# Out:
# open_water                     -0.854152
# developed_open                 -0.273160
# developed_low                  -0.333846
# developed_medium               -0.241097
# developed_high                 -0.225026
# barren_land                    -0.029819
# deciduous_forest               -0.816647
# evergreen_forest               -0.044384
# mixed_forest                   -0.232131
# shrub                          -0.076921
# grassland                      -0.247348
# pasture_hay                    -0.448139
# cultivated_crops               -0.190795
# woody_wetlands                 -0.612995
# emergent_herbaceous_wetlands   -0.098358
# 0                              -0.215276
# perennial_ice                  -0.002957
# dtype: float64

# %% [markdown]
# ### Check that percentages sum to 100
#
# #### All Touched Data

# %%
all_touched = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_all_touched_keyed_percentage.pkl').iloc[:,:-1]
total = all_touched.apply(lambda x: x.sum(), axis='columns')
total.mean()
# Out:
# 100.0

# %% [markdown]
# #### Regular Data

# %%
frame = pd.read_pickle('./urban_county_data/NLCD_Urban_Counties_keyed_percentage.pkl').iloc[:,:-1]
total = frame.apply(lambda x: x.sum(), axis='columns')
total.mean()
# Out:
# 100.0

# %% [markdown]
# ## Convert Data to CSV

# %%
files = glob.glob('./urban_county_data/*.pkl')
for file in files:
    frame = pd.read_pickle(file)
    cols = frame.columns.tolist()
    cols.insert(0, 'NAME')
    cols = cols[:-1]
    frame = frame[cols]
    
    frame = frame.fillna(value=0)
    
    
    name = file[file.rfind('/')+1:file.rfind('.')]
    print(name)
    frame.to_csv(file[:file.rfind('/')] + '/csv_files/' + name + '.csv')
# Out:
# NLCD_Urban_Counties_keyed
# NLCD_Urban_Counties_all_touched_keyed_percentage
# NLCD_Urban_Counties
# NLCD_Urban_Counties_all_touched_keyed
# NLCD_Urban_Counties_keyed_percentage
# NLCD_Urban_Counties_all_touched

# %% [markdown]
# ## Conclusion
#
# We have acquired county-level land cover data using two different rasterization strategies: all_touched=False, and all_touched=True. The methods are shown respectively in the figure below.
#
# <br>
# <figure>
#     <img src="https://github.com/perrygeo/python-raster-stats/raw/master/docs/img/rasterization.png">
#     <figcaption>All_touched = False on the left, All_touched = True on the right</figcaption>
# </figure>
# <br><br>
#
#
# The all_touched option is typically used for rasterization when the raster pixel size is close to the shapefile's polygon size, but the land cover pixels have 30m resolution, which is very small compared to the county sizes.
#
# Therefore, I suggest to use the all_touched=False data-set.
#
# 1. NLCD_Urban_Counties: This contains the raw data created by zonal_stats
# 2. NLCD_Urban_Counties_keyed: Raw data but the columns are converted based on the Land Cover Key (ex. 11 --> Open Water)
# 3. **NLCD_Urban_Counties_keyed_percentage: Keyed data but the pixel counts have been converted to percentages**
#
# The last one is probably the one we want to use since it is easy to interpret.
